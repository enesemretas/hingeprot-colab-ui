# %% [markdown]
# <a href="https://colab.research.google.com/github/enesemretas/hingeprot-colab-ui/blob/main/notebooks/HingeProt_UI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo2.gif](data:image/gif;base64,...)
#
# **An Algorithm For Protein Hinge Prediction Using Elastic Network Models**

# %%
# @title Hingeprot26 -User Interface

import os, sys, subprocess

def _run_quiet(cmd):
    subprocess.run(cmd, shell=True, check=True,
                   stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# Go to /content without printing it
os.chdir("/content")

# Clone Repo
_run_quiet("rm -rf hingeprot-colab-ui")
_run_quiet("git clone -q https://github.com/enesemretas/hingeprot-colab-ui.git")

# Launch interface
sys.path.insert(0, "/content/hingeprot-colab-ui")
from hingeprot.ui import launch
launch()
# Out:
# HTML(value='\n    <style>\n    .hp-card {border:1px solid #e5e7eb; border-radius:14px; padding:14px 16px; marg…
# HTML(value='\n    <div class="hp-card">\n      <div class="hp-title">\n        <span style="display:inline-blo…
# ...
